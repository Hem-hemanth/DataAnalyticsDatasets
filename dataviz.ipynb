# %% [markdown]
# <a href="https://colab.research.google.com/github/Hem-hemanth/DataAnalyticsDatasets/blob/main/dataviz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly as ply
import seaborn as sb

# %%
print(sb.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
dataset1=sb.load_dataset('penguins')

# %%
dataset1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
dataset1=dataset1.dropna()

# %%
dataset1['species'].value_counts()
# Out:
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: species, dtype: int64

# %%
import plotly.express as px
fig=px.sunburst(dataset1,path=['species','sex','island'],values='body_mass_g')

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
male=dataset1[dataset1.sex=='Male']
male=male['body_mass_g']
female=dataset1[dataset1.sex!='Male']

# %%
print(dataset1.groupby(['species','sex'])['body_mass_g'].mean())
# Out:
# species    sex
# Adelie     Female    3368.835616
#            Male      4043.493151
# Chinstrap  Female    3527.205882
#            Male      3938.970588
# Gentoo     Female    4679.741379
#            Male      5484.836066
# Name: body_mass_g, dtype: float64

# %%
dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Adelie']
# Out:
# sex
# Female    3368.835616
# Male      4043.493151
# Name: body_mass_g, dtype: float64

# %%
index1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 13   Adelie  Torgersen            38.6           21.2              191.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# ..      ...        ...             ...            ...                ...
# 333  Gentoo     Biscoe            51.5           16.3              230.0
# 335  Gentoo     Biscoe            55.1           16.0              230.0
# 337  Gentoo     Biscoe            48.8           16.2              222.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g   sex
# 0         3750.0  Male
# 5         3650.0  Male
# ...

# %%
from statistics import mean

# %%
dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Gentoo'][0],dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Gentoo'][1]
# Out:
# 4207.057057057057

# %%
sex=['Female','Male']
y1=[dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Adelie'][0],dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Adelie'][1]]
y2=[dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Chinstrap'][0],dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Chinstrap'][1]]
y3=[dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Gentoo'][0],dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Gentoo'][1]]

# %%
y1=[round(i) for i in y1]
y2=[round(i) for i in y2]
y3=[round(i) for i in y3]

# %%
import plotly.graph_objects as go
fig2=go.Figure(data=[go.Bar(name='Adelie',x=sex,y=[dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Adelie'][0],dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Adelie'][1]],text=y1,textposition='outside'),go.Bar(name='Chinstrap',x=sex,y=[dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Chinstrap'][0],dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Chinstrap'][1]],text=y2,textposition='outside'),go.Bar(name='Gentoo',x=sex,y=[dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Gentoo'][0],dataset1.groupby(['species','sex'])['body_mass_g'].mean()['Gentoo'][1]],text=y3,textposition='outside')])

# %%
fig2.update_layout(barmode='group')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dataset1.groupby(['species','sex'])['body_mass_g'].mean()
# Out:
# species    sex
# Adelie     Female    3368.835616
#            Male      4043.493151
# Chinstrap  Female    3527.205882
#            Male      3938.970588
# Gentoo     Female    4679.741379
#            Male      5484.836066
# Name: body_mass_g, dtype: float64

# %%
dataset2=sb.load_dataset('diamonds')

# %%
dataset2
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sc_x=dataset2['carat']
sc_y=dataset2['price']
color=np.random.uniform

# %%
dataset2.groupby(['color','cut'])['price'].mean()
# Out:
# color  cut
# D      Ideal        2629.094566
#        Premium      3631.292576
#        Very Good    3470.467284
#        Good         3405.382175
#        Fair         4291.061350
# E      Ideal        2597.550090
#        Premium      3538.914420
#        Very Good    3214.652083
#        Good         3423.644159
#        Fair         3682.312500
# F      Ideal        3374.939362
#        Premium      4324.890176
#        Very Good    3778.820240
#        Good         3495.750275
#        Fair         3827.003205
# G      Ideal        3720.706388
#        Premium      4500.742134
#        Very Good    3872.753806
#        Good         4123.482204
#        Fair         4239.254777
# H      Ideal        3889.334831
#        Premium      5216.706780
#        Very Good    4535.390351
#        Good         4276.254986
#        Fair         5135.683168
# I      Ideal        4451.970377
#        Premium      5946.180672
#        Very Good    5255.879568
#        Good         5078.532567
# ...

# %%
dataset2['clarity'].value_counts()
# Out:
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: clarity, dtype: int64

# %%
sb.scatterplot('carat','price',data=dataset2,hue='cut')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
dataset2['color'].value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
dataset3=sb.load_dataset('gammas')

# %%
dataset3
# Out:
#       timepoint  ROI  subject  BOLD signal
# 0           0.0  IPS        0     0.513433
# 1           0.0  IPS        1    -0.414368
# 2           0.0  IPS        2     0.214695
# 3           0.0  IPS        3     0.814809
# 4           0.0  IPS        4    -0.894992
# ...         ...  ...      ...          ...
# 5995       10.0   V1       15     0.068646
# 5996       10.0   V1       16     0.827451
# 5997       10.0   V1       17     1.363256
# 5998       10.0   V1       18     0.570810
# 5999       10.0   V1       19    -0.048178
#
# [6000 rows x 4 columns]

# %%
dataset3['ROI'].value_counts()
# Out:
# IPS    2000
# AG     2000
# V1     2000
# Name: ROI, dtype: int64

# %%
dataset3['subject'].value_counts()
# Out:
# 0     300
# 1     300
# 18    300
# 17    300
# 16    300
# 15    300
# 14    300
# 13    300
# 12    300
# 11    300
# 10    300
# 9     300
# 8     300
# 7     300
# 6     300
# 5     300
# 4     300
# 3     300
# 2     300
# 19    300
# Name: subject, dtype: int64

# %%
dataset2
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
fig3=px.treemap(dataset2,path=[px.Constant("Diamonds"),'color','cut'],values=dataset2['price'])

# %%
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dataset2.groupby(['color','cut'])['price'].sum()
# Out:
# color  cut
# D      Ideal         7450854
#        Premium       5820962
#        Very Good     5250817
#        Good          2254363
#        Fair           699443
# E      Ideal        10138238
#        Premium       8270443
#        Very Good     7715165
#        Good          3194260
#        Fair           824838
# F      Ideal        12912518
#        Premium      10081319
#        Very Good     8177367
#        Good          3177637
#        Fair          1194025
# G      Ideal        18171930
#        Premium      13160170
#        Very Good     8903461
#        Good          3591553
#        Fair          1331126
# H      Ideal        12115278
#        Premium      12311428
#        Very Good     8272552
#        Good          3001931
#        Fair          1556112
# I      Ideal         9317974
#        Premium       8491146
#        Very Good     6328079
#        Good          2650994
#        Fair           819953
# J      Ideal         4406695
# ...

# %%
fig4=px.sunburst(dataset2,path=['cut','color','price'],values='price')

# %%
dataset2
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]
