# %% [markdown]
# <a href="https://colab.research.google.com/github/Hem-hemanth/DataAnalyticsDatasets/blob/main/Copy_of_Copy_of_Copy_of_Copy_of_fashion_mnist_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Learning CNNs using Fashion-MNIST
#
# This assignment will bulld CNNS using the Fashion-MINST dataset. In particular, we will
# *   Use MNIST Fashion to study CNN architectures and parameters.
#
# Read more about the Fashion-MINST dataset in this paper [here](https://arxiv.org/abs/1708.07747) (**Fashion-MNIST: a Novel Image Dataset for Benchmarking Machine Learning Algorithms**)

# %% [markdown]
# ## Assignment Overview
#
#
# This assignment focuses on how to classify **fashion_mnist** data with a simple **Convolutional Neural Network** in Keras.
# Keras is part of the core TensorFlow library, in addition to being an independent open source project.
#
# The [fashion_mnist](https://github.com/zalandoresearch/fashion-mnist) dataset consists of
# 60,000 train and 10,000 test instances. The aim is to classify an image into one of 10 categories. The possible categories/labals are:
#
# <br> **Label**	**Description**
# <br> 0 T-shirt/top
# <br> 1 Trouser
# <br> 2 Pullover
# <br> 3 Dress
# <br> 4 Coat
# <br> 5 Sandal
# <br> 6 Shirt
# <br> 7 Sneaker
# <br> 8 Bag
# <br> 9 Ankle boot
#
# Each gray-scale input is a 28x28 low-resolution image.

# %% [markdown]
# >>[Learning CNNs using Fashion-MNIST](#scrollTo=XLMRPLVCFwEc)
#
# >>[Notebook Overview](#scrollTo=Ixyte299ZZgk)
#
# >>[Download the fashion_mnist data](#scrollTo=LbCigZtNZZgl)
#
# >>[Visualize the data](#scrollTo=tWORMSC8FDR4)
#
# >>[Data normalization](#scrollTo=Zx-Ee6LHZZgt)
#
# >>[Split the data into train/validation/test data sets](#scrollTo=CFlNHktHBtru)
#
# >>[Create the basic model architecture](#scrollTo=HhalcO03ZZg3)
#
# >>[Compile the model](#scrollTo=FhxJ5dinZZg8)
#
# >>[Train the model](#scrollTo=DtOvh3YVZZg_)
#
# >>[Load Model with the best validation accuracy](#scrollTo=e-MGLwZQy05d)
#
# >>[Test Accuracy](#scrollTo=9RTRkan4yq5H)
#
# >>[Visualize prediction](#scrollTo=oJv7XEk10bOv)
#
# >>[Congragulations!](#scrollTo=8AehWdRAVKN5)

# %% [markdown]
# ## Download the fashion_mnist data
# First let's install TensorFlow version 1.8.0 and import Tensorflow. Then we download fashion-mnist which is one of the Keras datasets.

# %%
import tensorflow as tf

import numpy as np
import matplotlib.pyplot as plt

# Load the fashion-mnist pre-shuffled train data and test data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28) y_train shape: (60000,)

# %%
tf
# Out:
# <module 'tensorflow' from '/usr/local/lib/python3.7/dist-packages/tensorflow/__init__.py'>

# %% [markdown]
# ## Visualize the data

# %%
# Print training set shape - note there are 60,000 training data of image size of 28x28, 60,000 train labels)
print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)

# Print the number of training and test datasets
print(x_train.shape[0], 'train set')
print(x_test.shape[0], 'test set')

# Define the text labels
fashion_mnist_labels = ["T-shirt/top",  # index 0
                        "Trouser",      # index 1
                        "Pullover",     # index 2 
                        "Dress",        # index 3 
                        "Coat",         # index 4
                        "Sandal",       # index 5
                        "Shirt",        # index 6 
                        "Sneaker",      # index 7 
                        "Bag",          # index 8 
                        "Ankle boot"]   # index 9

# Image index, you can pick any number between 0 and 59,999
img_index = 5
# y_train contains the lables, ranging from 0 to 9
label_index = y_train[img_index]
# Print the label, for example 2 Pullover
print ("y = " + str(label_index) + " " +(fashion_mnist_labels[label_index]))
# # Show one of the images from the training dataset
plt.imshow(x_train[img_index])
# Out:
# x_train shape: (60000, 28, 28) y_train shape: (60000,)
# 60000 train set
# 10000 test set
# y = 2 Pullover

# %%
label_index
# Out:
# 2

# %% [markdown]
# ## Data normalization
# Normalize the data dimensions so that they are of approximately the same scale.

# %%
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
print("Number of train data - " + str(len(x_train)))
print("Number of test data - " + str(len(x_test)))
# Out:
# Number of train data - 60000
# Number of test data - 10000

# %% [markdown]
# ## Split the data into train/validation/test data sets
#
#
# *   Training data - used for training the model
# *   Validation data - used for tuning the hyperparameters and evaluate the models
# *   Test data - used to test the model after the model has gone through initial vetting by the validation set.

# %%
# Further break training data into train / validation sets (# put 5000 into validation set and keep remaining 55,000 for train)
(x_train, x_valid) = x_train[5000:], x_train[:5000] 
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# Reshape input data from (28, 28) to (28, 28, 1)
w, h = 28, 28
x_train = x_train.reshape(x_train.shape[0], w, h, 1)
x_valid = x_valid.reshape(x_valid.shape[0], w, h, 1)
x_test = x_test.reshape(x_test.shape[0], w, h, 1)

# One-hot encode the labels
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_valid = tf.keras.utils.to_categorical(y_valid, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Print training set shape
print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)

# Print the number of training, validation, and test datasets
print(x_train.shape[0], 'train set')
print(x_valid.shape[0], 'validation set')
print(x_test.shape[0], 'test set')
# Out:
# x_train shape: (55000, 28, 28, 1) y_train shape: (55000, 10)
# 55000 train set
# 5000 validation set
# 10000 test set

# %%
x_train.shape[0]
# Out:
# 55000

# %% [markdown]
# ## Create the basic model architecture
#
# There are two APIs for defining a model in Keras:
# 1. [Sequential model API](https://keras.io/models/sequential/)
# 2. [Functional API](https://keras.io/models/model/)
#
# In this assignment we are using the Sequential model API.
# If you are interested in a tutorial using the Functional API, checkout Sara Robinson's blog [Predicting the price of wine with the Keras Functional API and TensorFlow](https://medium.com/tensorflow/predicting-the-price-of-wine-with-the-keras-functional-api-and-tensorflow-a95d1c2c1b03).
#
# In defining the model we will be using some of these Keras APIs:
# *   Conv2D() [link text](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D/) - create a convolutional layer
# *   Pooling() [link text](https://keras.io/layers/pooling/) - create a pooling layer
# *   Dropout() [link text](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout) - apply drop out
#
# In the basic architecture we create two convolutional layers, and then an inference layer.
#
# The key parameters for a convolution layer are:
# for convolution--(a) number of convolution filters; (b) kernel size;
# for pooling--kernel for pooling-size;
# for dropout--dropout probability. We will refer to these as the convolution-layer parameters.
#
# The inference-layer parameters are:
# (a) hidden layer vector-size and activation;
# (b) dropout probability;
# (c) output-layer activation.
#
# When we design a network we can specify the CNN model using these parameters.

# %%
pip install ann_visualizer
# Out:
# Collecting ann_visualizer
#   Downloading ann_visualizer-2.5.tar.gz (4.7 kB)
# Building wheels for collected packages: ann-visualizer
#   Building wheel for ann-visualizer (setup.py) ... done
#   Created wheel for ann-visualizer: filename=ann_visualizer-2.5-py3-none-any.whl size=4168 sha256=0a4ff6a5e117f801dbf71a754280c5a68cdf6cfa79eb5500c8df86b64251a0f6
#   Stored in directory: /root/.cache/pip/wheels/1b/fc/58/2ab1c3b30350105929308becddda4fb59b1358e54f985e1f4a
# Successfully built ann-visualizer
# Installing collected packages: ann-visualizer
# Successfully installed ann-visualizer-2.5

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (0.10.1)

# %%
from ann_visualizer.visualize import ann_viz

# %%
ann_viz(model,view=True,filename="network.gv", title="My first neural network")

# %%
model = tf.keras.Sequential()

# Must define the input shape in the first layer of the neural network
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1))) 
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(0.3))

model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(0.3))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# Take a look at the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 64)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        8224
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 32)          0
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense (Dense)               (None, 256)               401664
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 412,778
# Trainable params: 412,778
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile the model
# Configure the learning process with compile() API before training the model. It receives three arguments:
#
# *   An optimizer
# *   A loss function
# *   A list of metrics

# %%
model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %% [markdown]
# ## Train the model
#
# Now let's train the model with fit() API.
#
# We use  the [ModelCheckpoint](https://keras.io/callbacks/#modelcheckpoint) API to save the model after every epoch. Set "save_best_only = True" to save only when the validation accuracy improves.

# %%
from keras.callbacks import ModelCheckpoint

checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose = 1, save_best_only=True)
model.fit(x_train,
         y_train,
         batch_size=64,
         epochs=10,
         validation_data=(x_valid, y_valid),
         callbacks=[checkpointer])
# Out:
# Epoch 1/10
# 860/860 [==============================] - ETA: 0s - loss: 0.6109 - accuracy: 0.7743
# Epoch 1: val_loss improved from inf to 0.37141, saving model to model.weights.best.hdf5
# 860/860 [==============================] - 19s 11ms/step - loss: 0.6109 - accuracy: 0.7743 - val_loss: 0.3714 - val_accuracy: 0.8680
# Epoch 2/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.4216 - accuracy: 0.8473
# Epoch 2: val_loss improved from 0.37141 to 0.32645, saving model to model.weights.best.hdf5
# 860/860 [==============================] - 8s 10ms/step - loss: 0.4216 - accuracy: 0.8473 - val_loss: 0.3265 - val_accuracy: 0.8814
# Epoch 3/10
# 854/860 [============================>.] - ETA: 0s - loss: 0.3755 - accuracy: 0.8632
# Epoch 3: val_loss improved from 0.32645 to 0.28955, saving model to model.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.3753 - accuracy: 0.8633 - val_loss: 0.2896 - val_accuracy: 0.8928
# Epoch 4/10
# 855/860 [============================>.] - ETA: 0s - loss: 0.3485 - accuracy: 0.8729
# Epoch 4: val_loss improved from 0.28955 to 0.28716, saving model to model.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.3480 - accuracy: 0.8731 - val_loss: 0.2872 - val_accuracy: 0.8966
# Epoch 5/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.3285 - accuracy: 0.8789
# Epoch 5: val_loss improved from 0.28716 to 0.26764, saving model to model.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.3284 - accuracy: 0.8789 - val_loss: 0.2676 - val_accuracy: 0.9008
# Epoch 6/10
# 855/860 [============================>.] - ETA: 0s - loss: 0.3170 - accuracy: 0.8829
# Epoch 6: val_loss improved from 0.26764 to 0.25369, saving model to model.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.3172 - accuracy: 0.8828 - val_loss: 0.2537 - val_accuracy: 0.9084
# Epoch 7/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.3010 - accuracy: 0.8898
# Epoch 7: val_loss improved from 0.25369 to 0.24938, saving model to model.weights.best.hdf5
# 860/860 [==============================] - 9s 10ms/step - loss: 0.3012 - accuracy: 0.8897 - val_loss: 0.2494 - val_accuracy: 0.9106
# Epoch 8/10
# 860/860 [==============================] - ETA: 0s - loss: 0.2919 - accuracy: 0.8925
# Epoch 8: val_loss improved from 0.24938 to 0.24789, saving model to model.weights.best.hdf5
# 860/860 [==============================] - 9s 10ms/step - loss: 0.2919 - accuracy: 0.8925 - val_loss: 0.2479 - val_accuracy: 0.9098
# Epoch 9/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.2820 - accuracy: 0.8968
# Epoch 9: val_loss improved from 0.24789 to 0.23261, saving model to model.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.2819 - accuracy: 0.8968 - val_loss: 0.2326 - val_accuracy: 0.9154
# Epoch 10/10
# 858/860 [============================>.] - ETA: 0s - loss: 0.2769 - accuracy: 0.8981
# Epoch 10: val_loss did not improve from 0.23261
# 860/860 [==============================] - 8s 9ms/step - loss: 0.2769 - accuracy: 0.8980 - val_loss: 0.2415 - val_accuracy: 0.9110

# %% [markdown]
# ## Load Model with the best validation accuracy

# %%
print(checkpointer)
# Out:
# <keras.callbacks.ModelCheckpoint object at 0x7f11200fe650>

# %%
# Load the weights with the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ## Test Accuracy

# %%
# Evaluate the model on test set
score = model.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.9050999879837036

# %% [markdown]
# ## Visualize prediction
# Now let's visualize the prediction using the model you just trained.
# First we get the predictions with the model from the test data.
# Then we print out 15 images from the test data set, and set the titles with the prediction (and the groud truth label).
# If the prediction matches the true label, the title will be green; otherwise it's displayed in red.

# %%
y_hat = model.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))

# %% [markdown]
# **MODEL 1 - conv filter size (32,32)**

# %%
checkpointer1

# %%
model1 = tf.keras.Sequential()

# Must define the input shape in the first layer of the neural network
model1.add(tf.keras.layers.Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1))) 
model1.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model1.add(tf.keras.layers.Dropout(0.3))

model1.add(tf.keras.layers.Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model1.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model1.add(tf.keras.layers.Dropout(0.3))

model1.add(tf.keras.layers.Flatten())
model1.add(tf.keras.layers.Dense(256, activation='relu'))
model1.add(tf.keras.layers.Dropout(0.5))
model1.add(tf.keras.layers.Dense(10, activation='softmax'))

# Take a look at the model summary
model1.summary()
model1.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
from keras.callbacks import ModelCheckpoint

checkpointer1 = ModelCheckpoint(filepath='model1.weights.best.hdf5', verbose = 1, save_best_only=True)
model1.fit(x_train,
         y_train,
         batch_size=64,
         epochs=10,
         validation_data=(x_valid, y_valid),
         callbacks=[checkpointer1])
model1.load_weights('model1.weights.best.hdf5')
# Evaluate the model on test set
score = model1.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
y_hat = model1.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 28, 28, 32)        160
#
#  max_pooling2d_12 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  dropout_18 (Dropout)        (None, 14, 14, 32)        0
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 32)        4128
#
#  max_pooling2d_13 (MaxPoolin  (None, 7, 7, 32)         0
#  g2D)
#
#  dropout_19 (Dropout)        (None, 7, 7, 32)          0
#
#  flatten_6 (Flatten)         (None, 1568)              0
#
#  dense_12 (Dense)            (None, 256)               401664
#
#  dropout_20 (Dropout)        (None, 256)               0
#
#  dense_13 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 408,522
# Trainable params: 408,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.6429 - accuracy: 0.7591
# Epoch 1: val_loss improved from inf to 0.39099, saving model to model1.weights.best.hdf5
# 860/860 [==============================] - 13s 8ms/step - loss: 0.6421 - accuracy: 0.7593 - val_loss: 0.3910 - val_accuracy: 0.8638
# Epoch 2/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.4387 - accuracy: 0.8400
# Epoch 2: val_loss improved from 0.39099 to 0.34247, saving model to model1.weights.best.hdf5
# 860/860 [==============================] - 7s 8ms/step - loss: 0.4388 - accuracy: 0.8400 - val_loss: 0.3425 - val_accuracy: 0.8776
# Epoch 3/10
# 858/860 [============================>.] - ETA: 0s - loss: 0.3917 - accuracy: 0.8564
# Epoch 3: val_loss improved from 0.34247 to 0.32470, saving model to model1.weights.best.hdf5
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3917 - accuracy: 0.8565 - val_loss: 0.3247 - val_accuracy: 0.8820
# Epoch 4/10
# 855/860 [============================>.] - ETA: 0s - loss: 0.3690 - accuracy: 0.8671
# Epoch 4: val_loss improved from 0.32470 to 0.29165, saving model to model1.weights.best.hdf5
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3689 - accuracy: 0.8671 - val_loss: 0.2916 - val_accuracy: 0.8952
# Epoch 5/10
# 853/860 [============================>.] - ETA: 0s - loss: 0.3484 - accuracy: 0.8714
# Epoch 5: val_loss improved from 0.29165 to 0.27680, saving model to model1.weights.best.hdf5
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3481 - accuracy: 0.8714 - val_loss: 0.2768 - val_accuracy: 0.8986
# Epoch 6/10
# 853/860 [============================>.] - ETA: 0s - loss: 0.3351 - accuracy: 0.8777
# Epoch 6: val_loss improved from 0.27680 to 0.26637, saving model to model1.weights.best.hdf5
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3354 - accuracy: 0.8775 - val_loss: 0.2664 - val_accuracy: 0.9012
# Epoch 7/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.3211 - accuracy: 0.8816
# Epoch 7: val_loss improved from 0.26637 to 0.25157, saving model to model1.weights.best.hdf5
# 860/860 [==============================] - 7s 9ms/step - loss: 0.3207 - accuracy: 0.8818 - val_loss: 0.2516 - val_accuracy: 0.9082
# Epoch 8/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.3074 - accuracy: 0.8872
# Epoch 8: val_loss improved from 0.25157 to 0.24909, saving model to model1.weights.best.hdf5
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3072 - accuracy: 0.8873 - val_loss: 0.2491 - val_accuracy: 0.9072
# Epoch 9/10
# 853/860 [============================>.] - ETA: 0s - loss: 0.3003 - accuracy: 0.8896
# Epoch 9: val_loss improved from 0.24909 to 0.24280, saving model to model1.weights.best.hdf5
# 860/860 [==============================] - 7s 8ms/step - loss: 0.2998 - accuracy: 0.8898 - val_loss: 0.2428 - val_accuracy: 0.9068
# Epoch 10/10
# 860/860 [==============================] - ETA: 0s - loss: 0.2916 - accuracy: 0.8929
# Epoch 10: val_loss did not improve from 0.24280
# 860/860 [==============================] - 7s 8ms/step - loss: 0.2916 - accuracy: 0.8929 - val_loss: 0.2436 - val_accuracy: 0.9074
#
#  Test accuracy: 0.9036999940872192

# %%
model2 = tf.keras.Sequential()

# Must define the input shape in the first layer of the neural network
model2.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1))) 
model2.add(tf.keras.layers.MaxPooling2D(pool_size=3))
model2.add(tf.keras.layers.Dropout(0.3))

model2.add(tf.keras.layers.Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model2.add(tf.keras.layers.MaxPooling2D(pool_size=3))
model2.add(tf.keras.layers.Dropout(0.3))

model2.add(tf.keras.layers.Flatten())
model2.add(tf.keras.layers.Dense(256, activation='relu'))
model2.add(tf.keras.layers.Dropout(0.5))
model2.add(tf.keras.layers.Dense(10, activation='softmax'))

# Take a look at the model summary
model2.summary()
model2.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
from keras.callbacks import ModelCheckpoint

checkpointer2 = ModelCheckpoint(filepath='model2.weights.best.hdf5', verbose = 1, save_best_only=True)
model2.fit(x_train,
         y_train,
         batch_size=64,
         epochs=10,
         validation_data=(x_valid, y_valid),
         callbacks=[checkpointer2])
model2.load_weights('model2.weights.best.hdf5')
# Evaluate the model on test set
score = model2.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
y_hat = model2.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 28, 28, 64)        320
#
#  max_pooling2d_20 (MaxPoolin  (None, 9, 9, 64)         0
#  g2D)
#
#  dropout_30 (Dropout)        (None, 9, 9, 64)          0
#
#  conv2d_21 (Conv2D)          (None, 9, 9, 32)          8224
#
#  max_pooling2d_21 (MaxPoolin  (None, 3, 3, 32)         0
#  g2D)
#
#  dropout_31 (Dropout)        (None, 3, 3, 32)          0
#
#  flatten_10 (Flatten)        (None, 288)               0
#
#  dense_20 (Dense)            (None, 256)               73984
#
#  dropout_32 (Dropout)        (None, 256)               0
#
#  dense_21 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 85,098
# Trainable params: 85,098
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 858/860 [============================>.] - ETA: 0s - loss: 0.8352 - accuracy: 0.6826
# Epoch 1: val_loss improved from inf to 0.49993, saving model to model2.weights.best.hdf5
# 860/860 [==============================] - 9s 10ms/step - loss: 0.8348 - accuracy: 0.6827 - val_loss: 0.4999 - val_accuracy: 0.8110
# Epoch 2/10
# 860/860 [==============================] - ETA: 0s - loss: 0.5554 - accuracy: 0.7906
# Epoch 2: val_loss improved from 0.49993 to 0.41414, saving model to model2.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.5554 - accuracy: 0.7906 - val_loss: 0.4141 - val_accuracy: 0.8480
# Epoch 3/10
# 855/860 [============================>.] - ETA: 0s - loss: 0.4931 - accuracy: 0.8171
# Epoch 3: val_loss improved from 0.41414 to 0.36281, saving model to model2.weights.best.hdf5
# 860/860 [==============================] - 8s 10ms/step - loss: 0.4931 - accuracy: 0.8172 - val_loss: 0.3628 - val_accuracy: 0.8672
# Epoch 4/10
# 860/860 [==============================] - ETA: 0s - loss: 0.4583 - accuracy: 0.8316
# Epoch 4: val_loss improved from 0.36281 to 0.33399, saving model to model2.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.4583 - accuracy: 0.8316 - val_loss: 0.3340 - val_accuracy: 0.8736
# Epoch 5/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.4290 - accuracy: 0.8407
# Epoch 5: val_loss improved from 0.33399 to 0.31841, saving model to model2.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.4288 - accuracy: 0.8407 - val_loss: 0.3184 - val_accuracy: 0.8834
# Epoch 6/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.4139 - accuracy: 0.8469
# Epoch 6: val_loss improved from 0.31841 to 0.30357, saving model to model2.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.4135 - accuracy: 0.8471 - val_loss: 0.3036 - val_accuracy: 0.8916
# Epoch 7/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.3999 - accuracy: 0.8520
# Epoch 7: val_loss improved from 0.30357 to 0.30225, saving model to model2.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.3999 - accuracy: 0.8520 - val_loss: 0.3022 - val_accuracy: 0.8832
# Epoch 8/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.3842 - accuracy: 0.8582
# Epoch 8: val_loss improved from 0.30225 to 0.29115, saving model to model2.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.3842 - accuracy: 0.8582 - val_loss: 0.2911 - val_accuracy: 0.8932
# Epoch 9/10
# 858/860 [============================>.] - ETA: 0s - loss: 0.3769 - accuracy: 0.8590
# Epoch 9: val_loss improved from 0.29115 to 0.27604, saving model to model2.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.3768 - accuracy: 0.8591 - val_loss: 0.2760 - val_accuracy: 0.9004
# Epoch 10/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.3690 - accuracy: 0.8625
# Epoch 10: val_loss improved from 0.27604 to 0.27290, saving model to model2.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.3692 - accuracy: 0.8624 - val_loss: 0.2729 - val_accuracy: 0.9016
#
#  Test accuracy: 0.8877999782562256

# %%
model3 = tf.keras.Sequential()

# Must define the input shape in the first layer of the neural network
model3.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1))) 
model3.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model3.add(tf.keras.layers.Dropout(0.5))

model3.add(tf.keras.layers.Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model3.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model3.add(tf.keras.layers.Dropout(0.25))

model3.add(tf.keras.layers.Flatten())
model3.add(tf.keras.layers.Dense(256, activation='relu'))
model3.add(tf.keras.layers.Dropout(0.5))
model3.add(tf.keras.layers.Dense(10, activation='softmax'))

# Take a look at the model summary
model3.summary()
model3.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
from keras.callbacks import ModelCheckpoint

checkpointer3 = ModelCheckpoint(filepath='model3.weights.best.hdf5', verbose = 1, save_best_only=True)
model3.fit(x_train,
         y_train,
         batch_size=64,
         epochs=10,
         validation_data=(x_valid, y_valid),
         callbacks=[checkpointer3])
model3.load_weights('model3.weights.best.hdf5')
# Evaluate the model on test set
score = model3.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
y_hat = model3.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 28, 28, 64)        320
#
#  max_pooling2d_22 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  dropout_33 (Dropout)        (None, 14, 14, 64)        0
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 32)        8224
#
#  max_pooling2d_23 (MaxPoolin  (None, 7, 7, 32)         0
#  g2D)
#
#  dropout_34 (Dropout)        (None, 7, 7, 32)          0
#
#  flatten_11 (Flatten)        (None, 1568)              0
#
#  dense_22 (Dense)            (None, 256)               401664
#
#  dropout_35 (Dropout)        (None, 256)               0
#
#  dense_23 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 412,778
# Trainable params: 412,778
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.6307 - accuracy: 0.7654
# Epoch 1: val_loss improved from inf to 0.41306, saving model to model3.weights.best.hdf5
# 860/860 [==============================] - 53s 10ms/step - loss: 0.6305 - accuracy: 0.7655 - val_loss: 0.4131 - val_accuracy: 0.8530
# Epoch 2/10
# 860/860 [==============================] - ETA: 0s - loss: 0.4454 - accuracy: 0.8390
# Epoch 2: val_loss improved from 0.41306 to 0.34682, saving model to model3.weights.best.hdf5
# 860/860 [==============================] - 8s 10ms/step - loss: 0.4454 - accuracy: 0.8390 - val_loss: 0.3468 - val_accuracy: 0.8796
# Epoch 3/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.3959 - accuracy: 0.8562
# Epoch 3: val_loss improved from 0.34682 to 0.30417, saving model to model3.weights.best.hdf5
# 860/860 [==============================] - 8s 10ms/step - loss: 0.3958 - accuracy: 0.8562 - val_loss: 0.3042 - val_accuracy: 0.8878
# Epoch 4/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.3671 - accuracy: 0.8663
# Epoch 4: val_loss improved from 0.30417 to 0.28891, saving model to model3.weights.best.hdf5
# 860/860 [==============================] - 8s 10ms/step - loss: 0.3668 - accuracy: 0.8664 - val_loss: 0.2889 - val_accuracy: 0.8972
# Epoch 5/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.3456 - accuracy: 0.8735
# Epoch 5: val_loss improved from 0.28891 to 0.27134, saving model to model3.weights.best.hdf5
# 860/860 [==============================] - 8s 10ms/step - loss: 0.3456 - accuracy: 0.8735 - val_loss: 0.2713 - val_accuracy: 0.9020
# Epoch 6/10
# 855/860 [============================>.] - ETA: 0s - loss: 0.3287 - accuracy: 0.8805
# Epoch 6: val_loss improved from 0.27134 to 0.25882, saving model to model3.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.3292 - accuracy: 0.8804 - val_loss: 0.2588 - val_accuracy: 0.9056
# Epoch 7/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.3153 - accuracy: 0.8830
# Epoch 7: val_loss improved from 0.25882 to 0.25592, saving model to model3.weights.best.hdf5
# 860/860 [==============================] - 8s 10ms/step - loss: 0.3154 - accuracy: 0.8829 - val_loss: 0.2559 - val_accuracy: 0.9086
# Epoch 8/10
# 855/860 [============================>.] - ETA: 0s - loss: 0.3047 - accuracy: 0.8880
# Epoch 8: val_loss improved from 0.25592 to 0.24599, saving model to model3.weights.best.hdf5
# 860/860 [==============================] - 8s 10ms/step - loss: 0.3045 - accuracy: 0.8881 - val_loss: 0.2460 - val_accuracy: 0.9104
# Epoch 9/10
# 854/860 [============================>.] - ETA: 0s - loss: 0.2959 - accuracy: 0.8918
# Epoch 9: val_loss improved from 0.24599 to 0.24497, saving model to model3.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.2956 - accuracy: 0.8919 - val_loss: 0.2450 - val_accuracy: 0.9104
# Epoch 10/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.2916 - accuracy: 0.8939
# Epoch 10: val_loss improved from 0.24497 to 0.23855, saving model to model3.weights.best.hdf5
# 860/860 [==============================] - 8s 10ms/step - loss: 0.2913 - accuracy: 0.8940 - val_loss: 0.2386 - val_accuracy: 0.9118
#
#  Test accuracy: 0.9071000218391418

# %%
model4 = tf.keras.Sequential()

# Must define the input shape in the first layer of the neural network
model4.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1))) 
model4.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model4.add(tf.keras.layers.Dropout(0.3))

model4.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model4.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model4.add(tf.keras.layers.Dropout(0.3))

model4.add(tf.keras.layers.Flatten())
model4.add(tf.keras.layers.Dense(256, activation='relu'))
model4.add(tf.keras.layers.Dropout(0.5))
model4.add(tf.keras.layers.Dense(10, activation='softmax'))

# Take a look at the model summary
model4.summary()
model4.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
from keras.callbacks import ModelCheckpoint

checkpointer4 = ModelCheckpoint(filepath='model4.weights.best.hdf5', verbose = 1, save_best_only=True)
model4.fit(x_train,
         y_train,
         batch_size=64,
         epochs=10,
         validation_data=(x_valid, y_valid),
         callbacks=[checkpointer4])
model4.load_weights('model4.weights.best.hdf5')
# Evaluate the model on test set
score = model4.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
y_hat = model4.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 28, 28, 64)        320
#
#  max_pooling2d_24 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  dropout_36 (Dropout)        (None, 14, 14, 64)        0
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 64)        16448
#
#  max_pooling2d_25 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  dropout_37 (Dropout)        (None, 7, 7, 64)          0
#
#  flatten_12 (Flatten)        (None, 3136)              0
#
#  dense_24 (Dense)            (None, 256)               803072
#
#  dropout_38 (Dropout)        (None, 256)               0
#
#  dense_25 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 822,410
# Trainable params: 822,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 860/860 [==============================] - ETA: 0s - loss: 0.5725 - accuracy: 0.7895
# Epoch 1: val_loss improved from inf to 0.35268, saving model to model4.weights.best.hdf5
# 860/860 [==============================] - 10s 11ms/step - loss: 0.5725 - accuracy: 0.7895 - val_loss: 0.3527 - val_accuracy: 0.8768
# Epoch 2/10
# 860/860 [==============================] - ETA: 0s - loss: 0.3927 - accuracy: 0.8573
# Epoch 2: val_loss improved from 0.35268 to 0.30069, saving model to model4.weights.best.hdf5
# 860/860 [==============================] - 9s 10ms/step - loss: 0.3927 - accuracy: 0.8573 - val_loss: 0.3007 - val_accuracy: 0.8904
# Epoch 3/10
# 858/860 [============================>.] - ETA: 0s - loss: 0.3498 - accuracy: 0.8732
# Epoch 3: val_loss improved from 0.30069 to 0.27864, saving model to model4.weights.best.hdf5
# 860/860 [==============================] - 9s 10ms/step - loss: 0.3498 - accuracy: 0.8732 - val_loss: 0.2786 - val_accuracy: 0.8964
# Epoch 4/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.3241 - accuracy: 0.8808
# Epoch 4: val_loss improved from 0.27864 to 0.26393, saving model to model4.weights.best.hdf5
# 860/860 [==============================] - 9s 10ms/step - loss: 0.3244 - accuracy: 0.8807 - val_loss: 0.2639 - val_accuracy: 0.9078
# Epoch 5/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.3010 - accuracy: 0.8903
# Epoch 5: val_loss improved from 0.26393 to 0.24880, saving model to model4.weights.best.hdf5
# 860/860 [==============================] - 9s 10ms/step - loss: 0.3011 - accuracy: 0.8903 - val_loss: 0.2488 - val_accuracy: 0.9066
# Epoch 6/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.2841 - accuracy: 0.8949
# Epoch 6: val_loss did not improve from 0.24880
# 860/860 [==============================] - 9s 10ms/step - loss: 0.2841 - accuracy: 0.8949 - val_loss: 0.2501 - val_accuracy: 0.9048
# Epoch 7/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.2714 - accuracy: 0.8993
# Epoch 7: val_loss improved from 0.24880 to 0.22790, saving model to model4.weights.best.hdf5
# 860/860 [==============================] - 9s 10ms/step - loss: 0.2713 - accuracy: 0.8993 - val_loss: 0.2279 - val_accuracy: 0.9176
# Epoch 8/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.2609 - accuracy: 0.9038
# Epoch 8: val_loss improved from 0.22790 to 0.22670, saving model to model4.weights.best.hdf5
# 860/860 [==============================] - 9s 10ms/step - loss: 0.2610 - accuracy: 0.9038 - val_loss: 0.2267 - val_accuracy: 0.9196
# Epoch 9/10
# 855/860 [============================>.] - ETA: 0s - loss: 0.2490 - accuracy: 0.9081
# Epoch 9: val_loss improved from 0.22670 to 0.21764, saving model to model4.weights.best.hdf5
# 860/860 [==============================] - 9s 10ms/step - loss: 0.2490 - accuracy: 0.9081 - val_loss: 0.2176 - val_accuracy: 0.9210
# Epoch 10/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.2434 - accuracy: 0.9104
# Epoch 10: val_loss improved from 0.21764 to 0.21251, saving model to model4.weights.best.hdf5
# 860/860 [==============================] - 9s 10ms/step - loss: 0.2434 - accuracy: 0.9104 - val_loss: 0.2125 - val_accuracy: 0.9226
#
#  Test accuracy: 0.9161999821662903

# %%
model5 = tf.keras.Sequential()

# Must define the input shape in the first layer of the neural network
model5.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1))) 
model5.add(tf.keras.layers.MaxPooling2D(pool_size=4))
model5.add(tf.keras.layers.Dropout(0.3))

model5.add(tf.keras.layers.Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model5.add(tf.keras.layers.MaxPooling2D(pool_size=4))
model5.add(tf.keras.layers.Dropout(0.3))

model5.add(tf.keras.layers.Flatten())
model5.add(tf.keras.layers.Dense(256, activation='relu'))
model5.add(tf.keras.layers.Dropout(0.5))
model5.add(tf.keras.layers.Dense(10, activation='softmax'))

# Take a look at the model summary
model5.summary()
model5.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
from keras.callbacks import ModelCheckpoint

checkpointer5 = ModelCheckpoint(filepath='model5.weights.best.hdf5', verbose = 1, save_best_only=True)
model5.fit(x_train,
         y_train,
         batch_size=64,
         epochs=10,
         validation_data=(x_valid, y_valid),
         callbacks=[checkpointer5])
model5.load_weights('model5.weights.best.hdf5')
# Evaluate the model on test set
score = model5.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
y_hat = model5.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_26 (Conv2D)          (None, 28, 28, 64)        320
#
#  max_pooling2d_26 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  dropout_39 (Dropout)        (None, 7, 7, 64)          0
#
#  conv2d_27 (Conv2D)          (None, 7, 7, 32)          8224
#
#  max_pooling2d_27 (MaxPoolin  (None, 1, 1, 32)         0
#  g2D)
#
#  dropout_40 (Dropout)        (None, 1, 1, 32)          0
#
#  flatten_13 (Flatten)        (None, 32)                0
#
#  dense_26 (Dense)            (None, 256)               8448
#
#  dropout_41 (Dropout)        (None, 256)               0
#
#  dense_27 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 19,562
# Trainable params: 19,562
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 858/860 [============================>.] - ETA: 0s - loss: 1.2243 - accuracy: 0.5372
# Epoch 1: val_loss improved from inf to 0.72532, saving model to model5.weights.best.hdf5
# 860/860 [==============================] - 9s 10ms/step - loss: 1.2237 - accuracy: 0.5375 - val_loss: 0.7253 - val_accuracy: 0.7440
# Epoch 2/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.8719 - accuracy: 0.6783
# Epoch 2: val_loss improved from 0.72532 to 0.64353, saving model to model5.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.8718 - accuracy: 0.6784 - val_loss: 0.6435 - val_accuracy: 0.7700
# Epoch 3/10
# 854/860 [============================>.] - ETA: 0s - loss: 0.8079 - accuracy: 0.7013
# Epoch 3: val_loss improved from 0.64353 to 0.60472, saving model to model5.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.8077 - accuracy: 0.7013 - val_loss: 0.6047 - val_accuracy: 0.7800
# Epoch 4/10
# 854/860 [============================>.] - ETA: 0s - loss: 0.7597 - accuracy: 0.7199
# Epoch 4: val_loss improved from 0.60472 to 0.56526, saving model to model5.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.7596 - accuracy: 0.7199 - val_loss: 0.5653 - val_accuracy: 0.7922
# Epoch 5/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.7379 - accuracy: 0.7303
# Epoch 5: val_loss improved from 0.56526 to 0.54076, saving model to model5.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.7378 - accuracy: 0.7303 - val_loss: 0.5408 - val_accuracy: 0.8018
# Epoch 6/10
# 858/860 [============================>.] - ETA: 0s - loss: 0.7160 - accuracy: 0.7402
# Epoch 6: val_loss improved from 0.54076 to 0.53224, saving model to model5.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.7158 - accuracy: 0.7403 - val_loss: 0.5322 - val_accuracy: 0.8066
# Epoch 7/10
# 858/860 [============================>.] - ETA: 0s - loss: 0.6964 - accuracy: 0.7458
# Epoch 7: val_loss improved from 0.53224 to 0.53167, saving model to model5.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.6965 - accuracy: 0.7457 - val_loss: 0.5317 - val_accuracy: 0.8088
# Epoch 8/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.6908 - accuracy: 0.7502
# Epoch 8: val_loss improved from 0.53167 to 0.52163, saving model to model5.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.6907 - accuracy: 0.7501 - val_loss: 0.5216 - val_accuracy: 0.8162
# Epoch 9/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.6779 - accuracy: 0.7523
# Epoch 9: val_loss improved from 0.52163 to 0.51121, saving model to model5.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.6780 - accuracy: 0.7522 - val_loss: 0.5112 - val_accuracy: 0.8148
# Epoch 10/10
# 855/860 [============================>.] - ETA: 0s - loss: 0.6704 - accuracy: 0.7560
# Epoch 10: val_loss improved from 0.51121 to 0.50450, saving model to model5.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.6705 - accuracy: 0.7560 - val_loss: 0.5045 - val_accuracy: 0.8206
#
#  Test accuracy: 0.8037999868392944

# %%
model6 = tf.keras.Sequential()

# Must define the input shape in the first layer of the neural network
model6.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1))) 
model6.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model6.add(tf.keras.layers.Dropout(0.25))

model6.add(tf.keras.layers.Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model6.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model6.add(tf.keras.layers.Dropout(0.25))

model6.add(tf.keras.layers.Flatten())
model6.add(tf.keras.layers.Dense(256, activation='relu'))
model6.add(tf.keras.layers.Dropout(0.5))
model6.add(tf.keras.layers.Dense(10, activation='softmax'))

# Take a look at the model summary
model6.summary()
model6.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
from keras.callbacks import ModelCheckpoint

checkpointer6 = ModelCheckpoint(filepath='model6.weights.best.hdf5', verbose = 1, save_best_only=True)
model6.fit(x_train,
         y_train,
         batch_size=64,
         epochs=10,
         validation_data=(x_valid, y_valid),
         callbacks=[checkpointer6])
model6.load_weights('model6.weights.best.hdf5')
# Evaluate the model on test set
score = model6.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
y_hat = model6.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_28 (Conv2D)          (None, 28, 28, 64)        320
#
#  max_pooling2d_28 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  dropout_42 (Dropout)        (None, 14, 14, 64)        0
#
#  conv2d_29 (Conv2D)          (None, 14, 14, 32)        8224
#
#  max_pooling2d_29 (MaxPoolin  (None, 7, 7, 32)         0
#  g2D)
#
#  dropout_43 (Dropout)        (None, 7, 7, 32)          0
#
#  flatten_14 (Flatten)        (None, 1568)              0
#
#  dense_28 (Dense)            (None, 256)               401664
#
#  dropout_44 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 412,778
# Trainable params: 412,778
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 860/860 [==============================] - ETA: 0s - loss: 0.5755 - accuracy: 0.7901
# Epoch 1: val_loss improved from inf to 0.36487, saving model to model6.weights.best.hdf5
# 860/860 [==============================] - 10s 10ms/step - loss: 0.5755 - accuracy: 0.7901 - val_loss: 0.3649 - val_accuracy: 0.8694
# Epoch 2/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.3970 - accuracy: 0.8552
# Epoch 2: val_loss improved from 0.36487 to 0.32390, saving model to model6.weights.best.hdf5
# 860/860 [==============================] - 8s 10ms/step - loss: 0.3967 - accuracy: 0.8552 - val_loss: 0.3239 - val_accuracy: 0.8834
# Epoch 3/10
# 855/860 [============================>.] - ETA: 0s - loss: 0.3558 - accuracy: 0.8709
# Epoch 3: val_loss improved from 0.32390 to 0.29131, saving model to model6.weights.best.hdf5
# 860/860 [==============================] - 8s 10ms/step - loss: 0.3560 - accuracy: 0.8708 - val_loss: 0.2913 - val_accuracy: 0.8916
# Epoch 4/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.3297 - accuracy: 0.8805
# Epoch 4: val_loss improved from 0.29131 to 0.27170, saving model to model6.weights.best.hdf5
# 860/860 [==============================] - 8s 10ms/step - loss: 0.3295 - accuracy: 0.8806 - val_loss: 0.2717 - val_accuracy: 0.9002
# Epoch 5/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.3127 - accuracy: 0.8865
# Epoch 5: val_loss improved from 0.27170 to 0.25969, saving model to model6.weights.best.hdf5
# 860/860 [==============================] - 8s 10ms/step - loss: 0.3126 - accuracy: 0.8865 - val_loss: 0.2597 - val_accuracy: 0.9050
# Epoch 6/10
# 855/860 [============================>.] - ETA: 0s - loss: 0.2953 - accuracy: 0.8917
# Epoch 6: val_loss improved from 0.25969 to 0.25463, saving model to model6.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.2953 - accuracy: 0.8916 - val_loss: 0.2546 - val_accuracy: 0.9072
# Epoch 7/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.2843 - accuracy: 0.8942
# Epoch 7: val_loss improved from 0.25463 to 0.24703, saving model to model6.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.2843 - accuracy: 0.8942 - val_loss: 0.2470 - val_accuracy: 0.9094
# Epoch 8/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.2762 - accuracy: 0.8986
# Epoch 8: val_loss improved from 0.24703 to 0.23069, saving model to model6.weights.best.hdf5
# 860/860 [==============================] - 8s 9ms/step - loss: 0.2763 - accuracy: 0.8986 - val_loss: 0.2307 - val_accuracy: 0.9122
# Epoch 9/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.2663 - accuracy: 0.9026
# Epoch 9: val_loss did not improve from 0.23069
# 860/860 [==============================] - 8s 9ms/step - loss: 0.2663 - accuracy: 0.9026 - val_loss: 0.2326 - val_accuracy: 0.9120
# Epoch 10/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.2560 - accuracy: 0.9044
# Epoch 10: val_loss did not improve from 0.23069
# 860/860 [==============================] - 8s 9ms/step - loss: 0.2560 - accuracy: 0.9042 - val_loss: 0.2324 - val_accuracy: 0.9096
#
#  Test accuracy: 0.9067000150680542

# %%
model7 = tf.keras.Sequential()

# Must define the input shape in the first layer of the neural network
model7.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1))) 
model7.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model7.add(tf.keras.layers.Dropout(0.3))

model7.add(tf.keras.layers.Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model7.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model7.add(tf.keras.layers.Dropout(0.3))

model7.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model7.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model7.add(tf.keras.layers.Dropout(0.3))

model7.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model7.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model7.add(tf.keras.layers.Dropout(0.3))


model7.add(tf.keras.layers.Flatten())
model7.add(tf.keras.layers.Dense(256, activation='relu'))
model7.add(tf.keras.layers.Dropout(0.5))
model7.add(tf.keras.layers.Dense(10, activation='softmax'))

# Take a look at the model summary
model7.summary()
model7.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
from keras.callbacks import ModelCheckpoint

checkpointer7 = ModelCheckpoint(filepath='model7.weights.best.hdf5', verbose = 1, save_best_only=True)
model7.fit(x_train,
         y_train,
         batch_size=64,
         epochs=10,
         validation_data=(x_valid, y_valid),
         callbacks=[checkpointer7])
model7.load_weights('model7.weights.best.hdf5')
# Evaluate the model on test set
score = model7.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
y_hat = model7.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_30 (Conv2D)          (None, 28, 28, 64)        320
#
#  max_pooling2d_30 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  dropout_45 (Dropout)        (None, 14, 14, 64)        0
#
#  conv2d_31 (Conv2D)          (None, 14, 14, 32)        8224
#
#  max_pooling2d_31 (MaxPoolin  (None, 7, 7, 32)         0
#  g2D)
#
#  dropout_46 (Dropout)        (None, 7, 7, 32)          0
#
#  conv2d_32 (Conv2D)          (None, 7, 7, 64)          8256
#
#  max_pooling2d_32 (MaxPoolin  (None, 3, 3, 64)         0
#  g2D)
#
#  dropout_47 (Dropout)        (None, 3, 3, 64)          0
#
#  conv2d_33 (Conv2D)          (None, 3, 3, 64)          16448
#
#  max_pooling2d_33 (MaxPoolin  (None, 1, 1, 64)         0
#  g2D)
#
#  dropout_48 (Dropout)        (None, 1, 1, 64)          0
#
#  flatten_15 (Flatten)        (None, 64)                0
#
#  dense_30 (Dense)            (None, 256)               16640
#
#  dropout_49 (Dropout)        (None, 256)               0
#
#  dense_31 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 52,458
# Trainable params: 52,458
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 860/860 [==============================] - ETA: 0s - loss: 1.0125 - accuracy: 0.6114
# Epoch 1: val_loss improved from inf to 0.54158, saving model to model7.weights.best.hdf5
# 860/860 [==============================] - 11s 11ms/step - loss: 1.0125 - accuracy: 0.6114 - val_loss: 0.5416 - val_accuracy: 0.7894
# Epoch 2/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.6363 - accuracy: 0.7592
# Epoch 2: val_loss improved from 0.54158 to 0.45759, saving model to model7.weights.best.hdf5
# 860/860 [==============================] - 9s 11ms/step - loss: 0.6365 - accuracy: 0.7591 - val_loss: 0.4576 - val_accuracy: 0.8306
# Epoch 3/10
# 858/860 [============================>.] - ETA: 0s - loss: 0.5592 - accuracy: 0.7915
# Epoch 3: val_loss improved from 0.45759 to 0.39901, saving model to model7.weights.best.hdf5
# 860/860 [==============================] - 9s 11ms/step - loss: 0.5590 - accuracy: 0.7916 - val_loss: 0.3990 - val_accuracy: 0.8550
# Epoch 4/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.5144 - accuracy: 0.8136
# Epoch 4: val_loss improved from 0.39901 to 0.36734, saving model to model7.weights.best.hdf5
# 860/860 [==============================] - 9s 11ms/step - loss: 0.5142 - accuracy: 0.8136 - val_loss: 0.3673 - val_accuracy: 0.8686
# Epoch 5/10
# 858/860 [============================>.] - ETA: 0s - loss: 0.4793 - accuracy: 0.8267
# Epoch 5: val_loss improved from 0.36734 to 0.35040, saving model to model7.weights.best.hdf5
# 860/860 [==============================] - 9s 11ms/step - loss: 0.4796 - accuracy: 0.8266 - val_loss: 0.3504 - val_accuracy: 0.8704
# Epoch 6/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.4551 - accuracy: 0.8333
# Epoch 6: val_loss improved from 0.35040 to 0.34401, saving model to model7.weights.best.hdf5
# 860/860 [==============================] - 9s 11ms/step - loss: 0.4553 - accuracy: 0.8333 - val_loss: 0.3440 - val_accuracy: 0.8754
# Epoch 7/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.4383 - accuracy: 0.8413
# Epoch 7: val_loss improved from 0.34401 to 0.31461, saving model to model7.weights.best.hdf5
# 860/860 [==============================] - 9s 11ms/step - loss: 0.4383 - accuracy: 0.8413 - val_loss: 0.3146 - val_accuracy: 0.8836
# Epoch 8/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.4264 - accuracy: 0.8453
# Epoch 8: val_loss improved from 0.31461 to 0.30587, saving model to model7.weights.best.hdf5
# 860/860 [==============================] - 9s 11ms/step - loss: 0.4265 - accuracy: 0.8454 - val_loss: 0.3059 - val_accuracy: 0.8872
# Epoch 9/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.4119 - accuracy: 0.8514
# Epoch 9: val_loss improved from 0.30587 to 0.29986, saving model to model7.weights.best.hdf5
# 860/860 [==============================] - 9s 11ms/step - loss: 0.4120 - accuracy: 0.8514 - val_loss: 0.2999 - val_accuracy: 0.8884
# Epoch 10/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.4011 - accuracy: 0.8547
# Epoch 10: val_loss improved from 0.29986 to 0.29536, saving model to model7.weights.best.hdf5
# 860/860 [==============================] - 9s 11ms/step - loss: 0.4009 - accuracy: 0.8547 - val_loss: 0.2954 - val_accuracy: 0.8954
#
#  Test accuracy: 0.8884999752044678

# %%
model8= tf.keras.Sequential()

# Must define the input shape in the first layer of the neural network
model8.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=(28,28,1))) 
model8.add(tf.keras.layers.MaxPooling2D(pool_size=3))
model8.add(tf.keras.layers.Dropout(0.3))

model8.add(tf.keras.layers.Conv2D(filters=16, kernel_size=2, padding='same', activation='relu'))
model8.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model8.add(tf.keras.layers.Dropout(0.3))

model8.add(tf.keras.layers.Flatten())
model8.add(tf.keras.layers.Dense(256, activation='relu'))
model8.add(tf.keras.layers.Dropout(0.5))
model8.add(tf.keras.layers.Dense(10, activation='softmax'))

# Take a look at the model summary
model8.summary()
model8.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
from keras.callbacks import ModelCheckpoint

checkpointer8 = ModelCheckpoint(filepath='model8.weights.best.hdf5', verbose = 1, save_best_only=True)
model8.fit(x_train,
         y_train,
         batch_size=64,
         epochs=10,
         validation_data=(x_valid, y_valid),
         callbacks=[checkpointer8])
model8.load_weights('model8.weights.best.hdf5')
# Evaluate the model on test set
score = model8.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
y_hat = model8.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_34 (Conv2D)          (None, 28, 28, 32)        320
#
#  max_pooling2d_34 (MaxPoolin  (None, 9, 9, 32)         0
#  g2D)
#
#  dropout_50 (Dropout)        (None, 9, 9, 32)          0
#
#  conv2d_35 (Conv2D)          (None, 9, 9, 16)          2064
#
#  max_pooling2d_35 (MaxPoolin  (None, 4, 4, 16)         0
#  g2D)
#
#  dropout_51 (Dropout)        (None, 4, 4, 16)          0
#
#  flatten_16 (Flatten)        (None, 256)               0
#
#  dense_32 (Dense)            (None, 256)               65792
#
#  dropout_52 (Dropout)        (None, 256)               0
#
#  dense_33 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 70,746
# Trainable params: 70,746
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 860/860 [==============================] - ETA: 0s - loss: 0.8063 - accuracy: 0.6986
# Epoch 1: val_loss improved from inf to 0.46995, saving model to model8.weights.best.hdf5
# 860/860 [==============================] - 7s 7ms/step - loss: 0.8063 - accuracy: 0.6986 - val_loss: 0.4699 - val_accuracy: 0.8256
# Epoch 2/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.5541 - accuracy: 0.7940
# Epoch 2: val_loss improved from 0.46995 to 0.40618, saving model to model8.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.5541 - accuracy: 0.7940 - val_loss: 0.4062 - val_accuracy: 0.8510
# Epoch 3/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.4965 - accuracy: 0.8180
# Epoch 3: val_loss improved from 0.40618 to 0.37952, saving model to model8.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.4964 - accuracy: 0.8181 - val_loss: 0.3795 - val_accuracy: 0.8578
# Epoch 4/10
# 858/860 [============================>.] - ETA: 0s - loss: 0.4622 - accuracy: 0.8294
# Epoch 4: val_loss improved from 0.37952 to 0.34984, saving model to model8.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.4623 - accuracy: 0.8294 - val_loss: 0.3498 - val_accuracy: 0.8740
# Epoch 5/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.4370 - accuracy: 0.8379
# Epoch 5: val_loss improved from 0.34984 to 0.33943, saving model to model8.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.4372 - accuracy: 0.8378 - val_loss: 0.3394 - val_accuracy: 0.8738
# Epoch 6/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.4198 - accuracy: 0.8438
# Epoch 6: val_loss improved from 0.33943 to 0.30876, saving model to model8.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.4196 - accuracy: 0.8439 - val_loss: 0.3088 - val_accuracy: 0.8860
# Epoch 7/10
# 860/860 [==============================] - ETA: 0s - loss: 0.4018 - accuracy: 0.8497
# Epoch 7: val_loss improved from 0.30876 to 0.30660, saving model to model8.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.4018 - accuracy: 0.8497 - val_loss: 0.3066 - val_accuracy: 0.8864
# Epoch 8/10
# 853/860 [============================>.] - ETA: 0s - loss: 0.3961 - accuracy: 0.8537
# Epoch 8: val_loss improved from 0.30660 to 0.29719, saving model to model8.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.3962 - accuracy: 0.8537 - val_loss: 0.2972 - val_accuracy: 0.8880
# Epoch 9/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.3837 - accuracy: 0.8581
# Epoch 9: val_loss improved from 0.29719 to 0.28564, saving model to model8.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.3838 - accuracy: 0.8580 - val_loss: 0.2856 - val_accuracy: 0.8946
# Epoch 10/10
# 852/860 [============================>.] - ETA: 0s - loss: 0.3752 - accuracy: 0.8612
# Epoch 10: val_loss improved from 0.28564 to 0.27774, saving model to model8.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.3751 - accuracy: 0.8614 - val_loss: 0.2777 - val_accuracy: 0.8970
#
#  Test accuracy: 0.8895999789237976

# %%
model9= tf.keras.Sequential()

# Must define the input shape in the first layer of the neural network
model9.add(tf.keras.layers.Conv2D(filters=32, kernel_size=5, padding='same', activation='relu', input_shape=(28,28,1))) 
model9.add(tf.keras.layers.MaxPooling2D(pool_size=3))
model9.add(tf.keras.layers.Dropout(0.4))

model9.add(tf.keras.layers.Conv2D(filters=16, kernel_size=5, padding='same', activation='relu'))
model9.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model9.add(tf.keras.layers.Dropout(0.3))

model9.add(tf.keras.layers.Flatten())
model9.add(tf.keras.layers.Dense(256, activation='relu'))
model9.add(tf.keras.layers.Dropout(0.5))
model9.add(tf.keras.layers.Dense(10, activation='softmax'))

# Take a look at the model summary
model9.summary()
model9.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
from keras.callbacks import ModelCheckpoint

checkpointer9 = ModelCheckpoint(filepath='model9.weights.best.hdf5', verbose = 1, save_best_only=True)
model9.fit(x_train,
         y_train,
         batch_size=64,
         epochs=10,
         validation_data=(x_valid, y_valid),
         callbacks=[checkpointer9])
model9.load_weights('model9.weights.best.hdf5')
# Evaluate the model on test set
score = model9.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
y_hat = model9.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 28, 28, 32)        832
#
#  max_pooling2d_36 (MaxPoolin  (None, 9, 9, 32)         0
#  g2D)
#
#  dropout_53 (Dropout)        (None, 9, 9, 32)          0
#
#  conv2d_37 (Conv2D)          (None, 9, 9, 16)          12816
#
#  max_pooling2d_37 (MaxPoolin  (None, 4, 4, 16)         0
#  g2D)
#
#  dropout_54 (Dropout)        (None, 4, 4, 16)          0
#
#  flatten_17 (Flatten)        (None, 256)               0
#
#  dense_34 (Dense)            (None, 256)               65792
#
#  dropout_55 (Dropout)        (None, 256)               0
#
#  dense_35 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 82,010
# Trainable params: 82,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 860/860 [==============================] - ETA: 0s - loss: 0.7360 - accuracy: 0.7280
# Epoch 1: val_loss improved from inf to 0.40667, saving model to model9.weights.best.hdf5
# 860/860 [==============================] - 7s 8ms/step - loss: 0.7360 - accuracy: 0.7280 - val_loss: 0.4067 - val_accuracy: 0.8528
# Epoch 2/10
# 853/860 [============================>.] - ETA: 0s - loss: 0.4788 - accuracy: 0.8254
# Epoch 2: val_loss improved from 0.40667 to 0.34312, saving model to model9.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.4791 - accuracy: 0.8252 - val_loss: 0.3431 - val_accuracy: 0.8732
# Epoch 3/10
# 855/860 [============================>.] - ETA: 0s - loss: 0.4288 - accuracy: 0.8434
# Epoch 3: val_loss improved from 0.34312 to 0.32830, saving model to model9.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.4293 - accuracy: 0.8433 - val_loss: 0.3283 - val_accuracy: 0.8794
# Epoch 4/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.4020 - accuracy: 0.8526
# Epoch 4: val_loss improved from 0.32830 to 0.30775, saving model to model9.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.4019 - accuracy: 0.8526 - val_loss: 0.3077 - val_accuracy: 0.8844
# Epoch 5/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.3840 - accuracy: 0.8584
# Epoch 5: val_loss improved from 0.30775 to 0.28921, saving model to model9.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.3837 - accuracy: 0.8585 - val_loss: 0.2892 - val_accuracy: 0.8900
# Epoch 6/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.3700 - accuracy: 0.8613
# Epoch 6: val_loss improved from 0.28921 to 0.28814, saving model to model9.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.3700 - accuracy: 0.8613 - val_loss: 0.2881 - val_accuracy: 0.8946
# Epoch 7/10
# 854/860 [============================>.] - ETA: 0s - loss: 0.3559 - accuracy: 0.8691
# Epoch 7: val_loss improved from 0.28814 to 0.27307, saving model to model9.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.3555 - accuracy: 0.8693 - val_loss: 0.2731 - val_accuracy: 0.8954
# Epoch 8/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.3503 - accuracy: 0.8691
# Epoch 8: val_loss improved from 0.27307 to 0.26825, saving model to model9.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.3503 - accuracy: 0.8691 - val_loss: 0.2682 - val_accuracy: 0.8992
# Epoch 9/10
# 860/860 [==============================] - ETA: 0s - loss: 0.3433 - accuracy: 0.8742
# Epoch 9: val_loss improved from 0.26825 to 0.26287, saving model to model9.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.3433 - accuracy: 0.8742 - val_loss: 0.2629 - val_accuracy: 0.9016
# Epoch 10/10
# 855/860 [============================>.] - ETA: 0s - loss: 0.3378 - accuracy: 0.8746
# Epoch 10: val_loss improved from 0.26287 to 0.26212, saving model to model9.weights.best.hdf5
# 860/860 [==============================] - 6s 7ms/step - loss: 0.3374 - accuracy: 0.8747 - val_loss: 0.2621 - val_accuracy: 0.8998
#
#  Test accuracy: 0.8956000208854675

# %%
model10= tf.keras.Sequential()

# Must define the input shape in the first layer of the neural network
model10.add(tf.keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu', input_shape=(28,28,1))) 
model10.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model10.add(tf.keras.layers.Dropout(0.3))

model10.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model10.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model10.add(tf.keras.layers.Dropout(0.25))

model10.add(tf.keras.layers.Flatten())
model10.add(tf.keras.layers.Dense(256, activation='relu'))
model10.add(tf.keras.layers.Dropout(0.5))
model10.add(tf.keras.layers.Dense(10, activation='softmax'))

# Take a look at the model summary
model10.summary()
model10.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
from keras.callbacks import ModelCheckpoint

checkpointer10 = ModelCheckpoint(filepath='model10.weights.best.hdf5', verbose = 1, save_best_only=True)
model10.fit(x_train,
         y_train,
         batch_size=64,
         epochs=10,
         validation_data=(x_valid, y_valid),
         callbacks=[checkpointer10])
model10.load_weights('model10.weights.best.hdf5')
# Evaluate the model on test set
score = model10.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
y_hat = model10.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_38 (Conv2D)          (None, 28, 28, 128)       1280
#
#  max_pooling2d_38 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  dropout_56 (Dropout)        (None, 14, 14, 128)       0
#
#  conv2d_39 (Conv2D)          (None, 14, 14, 64)        32832
#
#  max_pooling2d_39 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  dropout_57 (Dropout)        (None, 7, 7, 64)          0
#
#  flatten_18 (Flatten)        (None, 3136)              0
#
#  dense_36 (Dense)            (None, 256)               803072
#
#  dropout_58 (Dropout)        (None, 256)               0
#
#  dense_37 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 839,754
# Trainable params: 839,754
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 860/860 [==============================] - ETA: 0s - loss: 0.5362 - accuracy: 0.8053
# Epoch 1: val_loss improved from inf to 0.32394, saving model to model10.weights.best.hdf5
# 860/860 [==============================] - 13s 15ms/step - loss: 0.5362 - accuracy: 0.8053 - val_loss: 0.3239 - val_accuracy: 0.8832
# Epoch 2/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.3624 - accuracy: 0.8675
# Epoch 2: val_loss improved from 0.32394 to 0.28543, saving model to model10.weights.best.hdf5
# 860/860 [==============================] - 12s 14ms/step - loss: 0.3623 - accuracy: 0.8675 - val_loss: 0.2854 - val_accuracy: 0.8984
# Epoch 3/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.3184 - accuracy: 0.8838
# Epoch 3: val_loss improved from 0.28543 to 0.25400, saving model to model10.weights.best.hdf5
# 860/860 [==============================] - 12s 14ms/step - loss: 0.3185 - accuracy: 0.8837 - val_loss: 0.2540 - val_accuracy: 0.9076
# Epoch 4/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.2892 - accuracy: 0.8939
# Epoch 4: val_loss improved from 0.25400 to 0.23893, saving model to model10.weights.best.hdf5
# 860/860 [==============================] - 12s 14ms/step - loss: 0.2892 - accuracy: 0.8939 - val_loss: 0.2389 - val_accuracy: 0.9138
# Epoch 5/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.2731 - accuracy: 0.8988
# Epoch 5: val_loss improved from 0.23893 to 0.22267, saving model to model10.weights.best.hdf5
# 860/860 [==============================] - 12s 14ms/step - loss: 0.2730 - accuracy: 0.8988 - val_loss: 0.2227 - val_accuracy: 0.9190
# Epoch 6/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.2540 - accuracy: 0.9056
# Epoch 6: val_loss did not improve from 0.22267
# 860/860 [==============================] - 12s 14ms/step - loss: 0.2540 - accuracy: 0.9056 - val_loss: 0.2293 - val_accuracy: 0.9120
# Epoch 7/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.2415 - accuracy: 0.9106
# Epoch 7: val_loss improved from 0.22267 to 0.21432, saving model to model10.weights.best.hdf5
# 860/860 [==============================] - 12s 13ms/step - loss: 0.2415 - accuracy: 0.9107 - val_loss: 0.2143 - val_accuracy: 0.9220
# Epoch 8/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.2319 - accuracy: 0.9142
# Epoch 8: val_loss improved from 0.21432 to 0.20804, saving model to model10.weights.best.hdf5
# 860/860 [==============================] - 12s 14ms/step - loss: 0.2320 - accuracy: 0.9141 - val_loss: 0.2080 - val_accuracy: 0.9190
# Epoch 9/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.2172 - accuracy: 0.9190
# Epoch 9: val_loss improved from 0.20804 to 0.20291, saving model to model10.weights.best.hdf5
# 860/860 [==============================] - 12s 14ms/step - loss: 0.2176 - accuracy: 0.9189 - val_loss: 0.2029 - val_accuracy: 0.9226
# Epoch 10/10
# 858/860 [============================>.] - ETA: 0s - loss: 0.2127 - accuracy: 0.9213
# Epoch 10: val_loss did not improve from 0.20291
# 860/860 [==============================] - 12s 13ms/step - loss: 0.2128 - accuracy: 0.9213 - val_loss: 0.2032 - val_accuracy: 0.9210
#
#  Test accuracy: 0.9176999926567078

# %%
model11= tf.keras.Sequential()

# Must define the input shape in the first layer of the neural network
model11.add(tf.keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu', input_shape=(28,28,1))) 
model11.add(tf.keras.layers.MaxPooling2D(pool_size=3))
model11.add(tf.keras.layers.Dropout(0.4))

model11.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model11.add(tf.keras.layers.MaxPooling2D(pool_size=3))
model11.add(tf.keras.layers.Dropout(0.4))

model11.add(tf.keras.layers.Flatten())
model11.add(tf.keras.layers.Dense(256, activation='relu'))
model11.add(tf.keras.layers.Dropout(0.5))
model11.add(tf.keras.layers.Dense(10, activation='softmax'))

# Take a look at the model summary
model11.summary()
model11.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
from keras.callbacks import ModelCheckpoint

checkpointer11 = ModelCheckpoint(filepath='model11.weights.best.hdf5', verbose = 1, save_best_only=True)
model11.fit(x_train,
         y_train,
         batch_size=64,
         epochs=10,
         validation_data=(x_valid, y_valid),
         callbacks=[checkpointer11])
model11.load_weights('model11.weights.best.hdf5')
# Evaluate the model on test set
score = model11.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
y_hat = model11.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 28, 28, 128)       1280
#
#  max_pooling2d_40 (MaxPoolin  (None, 9, 9, 128)        0
#  g2D)
#
#  dropout_59 (Dropout)        (None, 9, 9, 128)         0
#
#  conv2d_41 (Conv2D)          (None, 9, 9, 64)          73792
#
#  max_pooling2d_41 (MaxPoolin  (None, 3, 3, 64)         0
#  g2D)
#
#  dropout_60 (Dropout)        (None, 3, 3, 64)          0
#
#  flatten_19 (Flatten)        (None, 576)               0
#
#  dense_38 (Dense)            (None, 256)               147712
#
#  dropout_61 (Dropout)        (None, 256)               0
#
#  dense_39 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 225,354
# Trainable params: 225,354
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 860/860 [==============================] - ETA: 0s - loss: 0.7105 - accuracy: 0.7363
# Epoch 1: val_loss improved from inf to 0.37429, saving model to model11.weights.best.hdf5
# 860/860 [==============================] - 11s 12ms/step - loss: 0.7105 - accuracy: 0.7363 - val_loss: 0.3743 - val_accuracy: 0.8682
# Epoch 2/10
# 860/860 [==============================] - ETA: 0s - loss: 0.4466 - accuracy: 0.8359
# Epoch 2: val_loss improved from 0.37429 to 0.32539, saving model to model11.weights.best.hdf5
# 860/860 [==============================] - 10s 12ms/step - loss: 0.4466 - accuracy: 0.8359 - val_loss: 0.3254 - val_accuracy: 0.8774
# Epoch 3/10
# 855/860 [============================>.] - ETA: 0s - loss: 0.3883 - accuracy: 0.8563
# Epoch 3: val_loss improved from 0.32539 to 0.30149, saving model to model11.weights.best.hdf5
# 860/860 [==============================] - 10s 11ms/step - loss: 0.3880 - accuracy: 0.8564 - val_loss: 0.3015 - val_accuracy: 0.8898
# Epoch 4/10
# 858/860 [============================>.] - ETA: 0s - loss: 0.3606 - accuracy: 0.8663
# Epoch 4: val_loss improved from 0.30149 to 0.27306, saving model to model11.weights.best.hdf5
# 860/860 [==============================] - 10s 12ms/step - loss: 0.3607 - accuracy: 0.8663 - val_loss: 0.2731 - val_accuracy: 0.9026
# Epoch 5/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.3409 - accuracy: 0.8746
# Epoch 5: val_loss improved from 0.27306 to 0.25469, saving model to model11.weights.best.hdf5
# 860/860 [==============================] - 10s 11ms/step - loss: 0.3411 - accuracy: 0.8745 - val_loss: 0.2547 - val_accuracy: 0.9050
# Epoch 6/10
# 860/860 [==============================] - ETA: 0s - loss: 0.3316 - accuracy: 0.8767
# Epoch 6: val_loss improved from 0.25469 to 0.25333, saving model to model11.weights.best.hdf5
# 860/860 [==============================] - 10s 11ms/step - loss: 0.3316 - accuracy: 0.8767 - val_loss: 0.2533 - val_accuracy: 0.9070
# Epoch 7/10
# 856/860 [============================>.] - ETA: 0s - loss: 0.3152 - accuracy: 0.8831
# Epoch 7: val_loss improved from 0.25333 to 0.24518, saving model to model11.weights.best.hdf5
# 860/860 [==============================] - 10s 12ms/step - loss: 0.3154 - accuracy: 0.8831 - val_loss: 0.2452 - val_accuracy: 0.9090
# Epoch 8/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.3092 - accuracy: 0.8879
# Epoch 8: val_loss improved from 0.24518 to 0.23980, saving model to model11.weights.best.hdf5
# 860/860 [==============================] - 10s 11ms/step - loss: 0.3090 - accuracy: 0.8880 - val_loss: 0.2398 - val_accuracy: 0.9138
# Epoch 9/10
# 857/860 [============================>.] - ETA: 0s - loss: 0.2998 - accuracy: 0.8874
# Epoch 9: val_loss improved from 0.23980 to 0.23851, saving model to model11.weights.best.hdf5
# 860/860 [==============================] - 10s 12ms/step - loss: 0.2995 - accuracy: 0.8875 - val_loss: 0.2385 - val_accuracy: 0.9118
# Epoch 10/10
# 859/860 [============================>.] - ETA: 0s - loss: 0.2982 - accuracy: 0.8906
# Epoch 10: val_loss improved from 0.23851 to 0.23179, saving model to model11.weights.best.hdf5
# 860/860 [==============================] - 10s 12ms/step - loss: 0.2982 - accuracy: 0.8906 - val_loss: 0.2318 - val_accuracy: 0.9126
#
#  Test accuracy: 0.9053000211715698

# %% [markdown]
# ## Task 1: Architecture Comparison
# The code given above is called the baseline architecture, and will successfully train a CNN to classify fashion-MNIST with near 90% accuracy.
# We now want to compare other different architectures.
#
# Each group must run 10 additional architectures:
#
#
# *   2 different combination of number of filters
# *   2 different combinations of kernels for (convolution, pooling)
# *   2 different dropout probability values
# *   1 new architecture with more layers
# *   3 experiments with combined changes
#
# Report the results in a table with the first column describing the architecture and the second column the predictive accuracy of the model on the data.
#
# Describe how the changes to architecture influence the change in accuracy, if there is any significant change. Specifically, describe:
# * impact of number of filters
# * impact of kernel size
# * impact of dropout probability
# * impact of number of layers
# * impact of combining multiple changes.
#
# ## Task 2: TensorFlow coding of model
# The second main task is to rewrite the high-level Keras code for the model using TensorFlow. The necessary code fragments are noted below. Please fill in the outstanding code and replace the Keras model with your TensorFlow model. Then compile the code to run the basic model configuration (baseline model).

# %%
def cnn_model():
  #def cnn_model(features, labels, mode) is more complex than is needed for this assignment    #Reshapinng the input
    input_layer = tf.reshape(features["x"], [-1, 28, 28, 1])
    
# TO DO: WRITE A FUNCTION TO INPUT A CONVOLUTION LAYER,
#   denoting inputs=input_layer,filters, kernel_size, padding="same",
#        activation

# TO DO: WRITE A FUNCTION TO INPUT A POOLING LAYER, 
#    denoting inputs pool_size, strides

# DEFINE THE MODEL USING THE CODE YOU JUST WROTE

     # Convolutional Layer #1 and Pooling Layer #1
    conv1 = 
    
    pool1 = tf.layers.max_pooling2d(inputs=conv1, pool_size=[2, 2], strides=2)
    
    # Convolutional Layer #2 and Pooling Layer #2

    
    dropout_1 = tf.layers.dropout(inputs=pool2, rate=0.25,training=mode == tf.estimator.ModeKeys.TRAIN )
    
    # Convolutional Layer #2 Pooling Layer #2   Dropout #2

    # TO DO: IMPLEMENT CODE FOR THE DECISION AND OUTPUT LAYERS

 # Take a look at the model summary
model.summary()

  #  make sure the model matches the baseline model
# Out:
#   File "<ipython-input-21-db526cd758b5>", line 15
#     conv1 =
#             ^
# SyntaxError: invalid syntax
