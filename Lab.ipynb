# %% [markdown]
# <a href="https://colab.research.google.com/github/Hem-hemanth/DataAnalyticsDatasets/blob/main/Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("https://github.com/Hem-hemanth/DataAnalyticsDatasets/blob/dc74027bd063510ede437e4d612f41eb078e49b9/bestsellers.csv?raw=True")

# %%
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
df.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %%
df.head()
# Out:
#                                                 Name  ...        Genre
# 0                      10-Day Green Smoothie Cleanse  ...  Non Fiction
# 1                                  11/22/63: A Novel  ...      Fiction
# 2            12 Rules for Life: An Antidote to Chaos  ...  Non Fiction
# 3                             1984 (Signet Classics)  ...      Fiction
# 4  5,000 Awesome Facts (About Everything!) (Natio...  ...  Non Fiction
#
# [5 rows x 7 columns]

# %% [markdown]
# **Data Selection and Removal**

# %% [markdown]
# a. Create a new data frame df_new from the original data frame that only has, and in this
# specific order, the columns author, year and price (mandatory to use the names of the
# columns).
#
# b. Create a data frame df_new that only contains the 2nd and 3rd columns (mandatory to
# use numbers for referring the columns) of the data frame only for the last row.
#
# c. Print the cheap books, considering that a book is cheap if its price is within the interval
# [0, 15].
#
# d. Change all the NaN values of the column reviews of the data frame to 1.
#
# e. Select and print on the screen the rows from the 14th to the 44th only for the columns
# price and year(mandatory to use the names of the columns).

# %%
df_new=df[['Author','Year','Price']]

# %%
df_new

# %%
df_new=df_new.iloc[:,1:]

# %%
df_new.head()
# Out:
#    Year  Price
# 0  2016      8
# 1  2011     22
# 2  2018     15
# 3  2017      6
# 4  2019     12

# %%
df_new=df.sort_values(by='Price')

# %%
df_new.head()
# Out:
#                                            Name       Author  ...  Year    Genre
# 42   Cabin Fever (Diary of a Wimpy Kid, Book 6)  Jeff Kinney  ...  2011  Fiction
# 71      Diary of a Wimpy Kid: Hard Luck, Book 8  Jeff Kinney  ...  2013  Fiction
# 381                                 The Getaway  Jeff Kinney  ...  2017  Fiction
# 116                 Frozen (Little Golden Book)    RH Disney  ...  2014  Fiction
# 505                       To Kill a Mockingbird   Harper Lee  ...  2013  Fiction
#
# [5 rows x 7 columns]

# %%
df[df['Price']<=15].count()
# Out:
# Name           408
# Author         408
# User Rating    408
# Reviews        408
# Price          408
# Year           408
# Genre          408
# dtype: int64

# %%
x=sum(1 for i in df_new['Price'] if i<=15)
x
# Out:
# 408

# %%
df_new.iloc[407:410]
# Out:
#                                                   Name  ...        Genre
# 464  The Subtle Art of Not Giving a F*ck: A Counter...  ...  Non Fiction
# 445                            The Paris Wife: A Novel  ...      Fiction
# 122  George Washington's Secret Six: The Spy Ring T...  ...  Non Fiction
#
# [3 rows x 7 columns]

# %%
df_new.iloc[:408,:-2]
# Out:
#                                                   Name  ... Price
# 42          Cabin Fever (Diary of a Wimpy Kid, Book 6)  ...     0
# 71             Diary of a Wimpy Kid: Hard Luck, Book 8  ...     0
# 381                                        The Getaway  ...     0
# 116                        Frozen (Little Golden Book)  ...     0
# 505                              To Kill a Mockingbird  ...     0
# ..                                                 ...  ...   ...
# 363  The Dukan Diet: 2 Steps to Lose the Weight, 2 ...  ...    15
# 75                                           Divergent  ...    15
# 76                                           Divergent  ...    15
# 34   Being Mortal: Medicine and What Matters in the...  ...    15
# 464  The Subtle Art of Not Giving a F*ck: A Counter...  ...    15
#
# [408 rows x 5 columns]

# %%
df.Reviews.dtype
# Out:
# dtype('int64')

# %%
df.Reviews.values
# Out:
# array([17350,  2052, 18979, 21424,  7665, 12643, 19735, 19699,  5983,
#        23848, 23848,   460,  4149,  5153,  5013,  2313,  2925,  2951,
#         2426,  9198, 36348, 36348,  6310, 15921, 12159,   798,  9374,
#          491,  5360,  1909,  1296,   615, 61133, 61133, 11113, 10070,
#        10070,  3729,  9769,   471, 14344, 14344,  4505, 10369, 16244,
#         2884, 22614, 22614, 22614,  4761,  1542,  1542,  1542,  6143,
#         4022,  3871,  4866,  4866,  1329,  4642,  1541,  1924,  2094,
#        10922, 10922, 10922, 10922,  2137,  1651,  6679,  6679,  6812,
#         3837,  6540,  7955, 27098, 27098, 17684,    37, 15845,  3181,
#         5062,  4786,  7235,  7235, 12619,  9089,  5470,  5118,  2134,
#         2525,   720,   956,  6346,  6346,  5505,  5505, 28729, 28729,
#         5413, 10721, 10721,  4370,  6042, 23631, 20262, 47265, 47265,
#        13964, 13677, 17323, 17323, 17323, 17323, 17323,  1555,  3642,
# ...

# %%
df.loc[14:45,['Price','Year']]
# Out:
#     Price  Year
# 14     17  2009
# 15      4  2016
# 16      6  2015
# 17      6  2015
# 18      8  2015
# 19     13  2016
# 20     14  2014
# 21     14  2015
# 22     13  2013
# 23      9  2015
# 24     13  2013
# 25      5  2009
# 26      9  2017
# 27     14  2010
# 28      5  2015
# 29     11  2015
# 30     24  2012
# 31     21  2010
# 32     11  2018
# 33     11  2019
# 34     15  2015
# 35     13  2015
# 36     13  2016
# 37     18  2016
# 38     13  2009
# 39      8  2010
# 40      5  2017
# 41      5  2019
# 42      0  2011
# 43      4  2016
# 44     18  2019
# 45     28  2014

# %% [markdown]
# **Data Analysis Questions.**
# a. Print on the screen the exact number of books that belong to the genre “Fiction”.
#
# b. Print ONLY the minimum price of the books for every type of genre (“Fiction”/ “Non
# Fiction”).
#
# c. Aggregate and print ONLY the minimum and mean values of every numeric column of
# the data frame.
#
# d. Group the rows of the data frame by their year and then print the maximum values of
# the numeric columns of the data frame for every group .
#
# e. Sort the books by their user rating. The smallest must be above .

# %%
df.groupby('Genre').count()
# Out:
#              Name  Author  User Rating  Reviews  Price  Year
# Genre
# Fiction       240     240          240      240    240   240
# Non Fiction   310     310          310      310    310   310

# %%
df.groupby('Genre')['Price'].min()
# Out:
# Genre
# Fiction        0
# Non Fiction    0
# Name: Price, dtype: int64

# %%
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
df.groupby(['Price','Genre']).count()
# Out:
#                    Name  Author  User Rating  Reviews  Year
# Price Genre
# 0     Fiction        11      11           11       11    11
#       Non Fiction     1       1            1        1     1
# 1     Non Fiction     1       1            1        1     1
# 2     Fiction         3       3            3        3     3
#       Non Fiction     2       2            2        2     2
# ...                 ...     ...          ...      ...   ...
# 52    Fiction         1       1            1        1     1
# 53    Non Fiction     1       1            1        1     1
# 54    Non Fiction     1       1            1        1     1
# 82    Fiction         1       1            1        1     1
# 105   Non Fiction     2       2            2        2     2
#
# [63 rows x 5 columns]

# %%
df.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %%
df_new=df[['User Rating','Reviews','Price','Year']]

# %%
df_new.agg(['mean','min'])
# Out:
#       User Rating       Reviews  Price    Year
# mean     4.618364  11953.281818   13.1  2014.0
# min      3.300000     37.000000    0.0  2009.0

# %%
df.groupby('Year')['User Rating','Reviews','Price'].max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#       User Rating  Reviews  Price
# Year
# 2009          4.8    19720     82
# 2010          4.8    32122     46
# 2011          4.9    32122     46
# 2012          4.9    57271     46
# 2013          4.9    57271    105
# 2014          4.9    57271    105
# 2015          4.9    79446     46
# 2016          4.9    79446     54
# 2017          4.9    29442     46
# 2018          4.9    61133     46
# 2019          4.9    87841     27

# %%
df_new=df.sort_values(by='User Rating')

# %%
df_new
# Out:
#                                                   Name  ...    Genre
# 353                                 The Casual Vacancy  ...  Fiction
# 132                         Go Set a Watchman: A Novel  ...  Fiction
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...  ...  Fiction
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...  ...  Fiction
# 393  The Goldfinch: A Novel (Pulitzer Prize for Fic...  ...  Fiction
# ..                                                 ...  ...      ...
# 41            Brown Bear, Brown Bear, What Do You See?  ...  Fiction
# 40            Brown Bear, Brown Bear, What Do You See?  ...  Fiction
# 247                          Oh, the Places You'll Go!  ...  Fiction
# 146  Goodnight, Goodnight Construction Site (Hardco...  ...  Fiction
# 249                          Oh, the Places You'll Go!  ...  Fiction
#
# [550 rows x 7 columns]

# %%
df.corr()
# Out:
#              User Rating   Reviews     Price      Year
# User Rating     1.000000 -0.001729 -0.133086  0.242383
# Reviews        -0.001729  1.000000 -0.109182  0.263560
# Price          -0.133086 -0.109182  1.000000 -0.153979
# Year            0.242383  0.263560 -0.153979  1.000000

# %%
import matplotlib.pyplot as plt
plt.plot(df['Reviews'],df['Price'])

# %%
plt.plot(df['Reviews'],df['User Rating'])
